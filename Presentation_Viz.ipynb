# %%
import mysql.connector
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import sys
from IPython.display import HTML
from matplotlib import pyplot as plt
from celluloid import Camera
import plotly.graph_objects as go

import networkx as nx

from IPython.display import HTML
from matplotlib import pyplot as plt
from celluloid import Camera
import collections


import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(2018)
import nltk
import ast
from random import shuffle

# %%
emails_df = pd.read_csv('Data/emails_tokenized.csv')
employee_df = pd.read_csv('Data/employee_keywords.csv')
network_df = pd.read_csv('Data/network.csv')

# %%
exec_list = ['CEO','President','Vice President']

# %%
emails_df = emails_df[~emails_df['token_subject'].isna()]

exec_list = ['CEO','President','Vice President']

job_count = collections.Counter()
for rank in emails_df['sender_level']:
    job_count[rank] +=1

# %%
employee_df
# Out:
#      Unnamed: 0  Unnamed: 0.1  eid first_name    last_name  \
# 0             0             0   18       Lynn        Blair
# 1             1             1   17       Mike      Grigsby
# 2             2             2   16   Michelle         Cash
# 3             3             3   15     Monika    Causholli
# 4             4             4   14    Richard      Sanders
# 5             5             5   13      Marie        Heard
# 6             6             6   12       Paul        Lucci
# 7             7             7   11       Mark        Whitt
# 8             8             8   10    Phillip        Allen
# 9             9             9    9  Stephanie        Panus
# 10           10            10    8      Susan      Pereira
# 11           11            11    7    Theresa        Staab
# 12           12            12    6       Mark       Taylor
# 13           13            13    5    Richard         Ring
# 14           14            14  136      Stacy      Dickson
# 15           15            15    4        Teb        Lokey
# 16           16            16    3      Tracy     Geaccone
# 17           17            17    2      Kevin        Hyatt
# 18           18            18    1     Robert       Badeer
# 19           19            19   19      Lindy       Donoho
# 20           20            20   20   Kimberly       Watson
# 21           21            21   21      Keith        Holst
# 22           22            22   22        Joe       Quenet
# 23           23            23   23      James      Steffes
# 24           24            24   24       John       Forney
# 25           25            25   25        Jay    Reitmeyer
# 26           26            26   26      Frank        Ermis
# 27           27            27   27  Elizabeth        Sager
# 28           28            28   28    Darrell  Schoolcraft
# 29           29            29   29      Danny      McCarty
# ..          ...           ...  ...        ...          ...
# 121         121           121  121     Robert       Benson
# 122         122           122  122      Sally         Beck
# 123         123           123  123       Rick          Buy
# 124         124           124  124        Don     Baughman
# 125         125           125  125       Eric         Bass
# 126         126           126  126     Hunter      Shively
# 127         127           127  127    Kenneth          Lay
# 128         128           128  128        Kam       Keiser
# 129         129           129  129    Jeffrey     Skilling
# 130         130           130  130       Sean     Crandall
# 131         131           131  131       Ryan      Slinger
# 132         132           132  132       Mike     Swerzbin
# 133         133           133  133      Diana     Scholtes
# 134         134           134  134      Craig         Dean
# 135         135           135  135       Bill     Williams
# 136         136           136  137       Drew       Fossum
# 137         137           137  138       Mark       Guzman
# 138         138           138  139       Mary         Hain
# 139         139           139  140       Lysa         Akin
# 140         140           140  141     Steven       Harris
# 141         141           141  142        Dan         Hyvl
# 142         142           142  143       Eric       Linder
# 143         143           143  144     Steven       Merris
# 144         144           144  145      Robin     Rodrigue
# 145         145           145  146     Steven        South
# 146         146           146  147      Carol        Clair
# 147         147           147  148      Chris      Stokley
# 148         148           148  149       Kate        Symes
# 149         149           149  150        Liz       Taylor
# 150         150           150  151    Rosalee      Fleming
#
#                           email_id  Unnamed: 0.1.1                 name  \
# 0             lynn.blair@enron.com           108.0           Lynn Blair
# 1           mike.grigsby@enron.com           126.0      Michael Grigsby
# 2          michelle.cash@enron.com           123.0        Michelle Cash
# 3       monika.causholli@enron.com           131.0     Monika Causholli
# 4             b..sanders@enron.com            12.0      Richard Sanders
# 5            marie.heard@enron.com           110.0          Marie Heard
# 6               t..lucci@enron.com           175.0           Paul Lucci
# 7             mark.whitt@enron.com           115.0           Mark Whitt
# 8               k..allen@enron.com            89.0         Philip Allen
# 9        stephanie.panus@enron.com           163.0      Stephanie Panus
# 10            w..pereira@enron.com           183.0        Susan Pereira
# 11         theresa.staab@enron.com           172.0        Theresa Staab
# 12                taylor@enron.com             NaN                  NaN
# 13          richard.ring@enron.com           145.0         Richard Ring
# 14         stacy.dickson@enron.com           161.0        Stacy Dickson
# 15             teb.lokey@enron.com           171.0            Teb Lokey
# 16        tracy.geaccone@enron.com           178.0       Tracy Geaccone
# 17           kevin.hyatt@enron.com            95.0          Kevin Hyatt
# 18         robert.badeer@enron.com           149.0        Robert Badeer
# 19          lindy.donoho@enron.com           103.0         Lindy Donoho
# 20       kimberly.watson@enron.com            98.0      Kimberly Watson
# 21           keith.holst@enron.com            93.0          Keith Holst
# 22            joe.quenet@enron.com            76.0           Joe Quenet
# 23            d..steffes@enron.com            34.0        James Steffes
# 24             m..forney@enron.com           121.0          John Forney
# 25         jay.reitmeyer@enron.com            62.0        Jay Reitmeyer
# 26           frank.ermis@enron.com            47.0          Frank Ermis
# 27       elizabeth.sager@enron.com            38.0      Elizabeth Sager
# 28   darrell.schoolcraft@enron.com            25.0  Darrell Schoolcraft
# 29         danny.mccarty@enron.com            23.0        Danny McCarty
# ..                             ...             ...                  ...
# 121        robert.benson@enron.com           150.0        Robert Benson
# 122           sally.beck@enron.com           154.0           Sally Beck
# 123             rick.buy@enron.com           148.0             Rick Buy
# 124         don.baughman@enron.com            32.0         Don Baughman
# 125            eric.bass@enron.com            39.0            Eric Bass
# 126           s..shively@enron.com           160.0       Hunter Shively
# 127          kenneth.lay@enron.com            94.0          Kenneth Lay
# 128           kam.keiser@enron.com            90.0           Kam Keiser
# 129        jeff.skilling@enron.com            67.0     Jeffery Skilling
# 130        sean.crandall@enron.com             NaN                  NaN
# 131         ryan.slinger@enron.com           153.0         Ryan Slinger
# 132        mike.swerzbin@enron.com           129.0        Mike Swerzbin
# 133       diana.scholtes@enron.com            30.0       Diana Scholtes
# 134           craig.dean@enron.com            20.0           Craig Dean
# 135        bill.williams@enron.com             9.0                  NaN
# 136          drew.fossum@enron.com            33.0          Drew Fossum
# 137          mark.guzman@enron.com             NaN                  NaN
# 138            mary.hain@enron.com             NaN                  NaN
# 139            lysa.akin@enron.com             NaN                  NaN
# 140        steven.harris@enron.com             NaN                  NaN
# 141             dan.hyvl@enron.com            22.0             Dan Hyvl
# 142          eric.linder@enron.com             NaN                  NaN
# 143        steven.merris@enron.com             NaN                  NaN
# 144       robin.rodrigue@enron.com             NaN                  NaN
# 145         steven.south@enron.com           165.0                  NaN
# 146          carol.clair@enron.com             NaN                  NaN
# 147        chris.stokley@enron.com             NaN                  NaN
# 148           kate.symes@enron.com            91.0           Kate Symes
# 149           liz.taylor@enron.com           105.0                  NaN
# 150      rosalee.fleming@enron.com             NaN                  NaN
#
#            job_rank                      job_title  \
# 0               NaN                            NaN
# 1           Manager                            NaN
# 2               NaN                            NaN
# 3          Employee        Analyst Risk Management
# 4    Vice President       Enron WholeSale Services
# 5               NaN                            NaN
# 6          Employee                            NaN
# 7               NaN                            NaN
# 8           Manager                            NaN
# 9          Employee                            NaN
# 10         Employee                            NaN
# 11         Employee                            NaN
# 12              NaN                            NaN
# 13         Employee                            NaN
# 14         Employee                            NaN
# 15          Manager             Regulatory Affairs
# 16         Employee                            NaN
# 17         Director              Pipeline Business
# 18         Director                            NaN
# 19         Employee                            NaN
# 20              NaN                            NaN
# 21         Director                            NaN
# 22           Trader                            NaN
# 23   Vice President             Government Affairs
# 24          Manager         Real time Trading Desk
# 25         Employee                            NaN
# 26         Director                            NaN
# 27         Employee                            NaN
# 28              NaN                            NaN
# 29   Vice President                            NaN
# ..              ...                            ...
# 121        Director                            NaN
# 122        Employee        Chief Operating Officer
# 123         Manager  Chief Risk Management Officer
# 124          Trader                            NaN
# 125          Trader                            NaN
# 126  Vice President                            NaN
# 127             CEO                            NaN
# 128        Employee                            NaN
# 129             CEO                            NaN
# 130             NaN                            NaN
# 131          Trader                            NaN
# 132          Trader                            NaN
# 133          Trader                            NaN
# 134          Trader                            NaN
# 135             NaN                            NaN
# 136  Vice President                            NaN
# 137             NaN                            NaN
# 138             NaN                            NaN
# 139             NaN                            NaN
# 140             NaN                            NaN
# 141        Employee                            NaN
# 142             NaN                            NaN
# 143             NaN                            NaN
# 144             NaN                            NaN
# 145             NaN                            NaN
# 146             NaN                            NaN
# 147             NaN                            NaN
# 148        Employee                            NaN
# 149             NaN                            NaN
# 150             NaN                            NaN
#
#                                              key_words
# 0    ['fw', 'oneok', 'meeting', 'tw', 'nng', 'gas',...
# 1    ['fw', 'west', 'meeting', 'desk', 'fundies', '...
# 2    ['fw', 'agreement', 'enron', 'employment', 'pr...
# 3    ['pulp', 'wrap', 'et', 'risi', 'foex', 'analys...
# 4    ['fw', 'synchronization', 'log', 'litigation',...
# 5    ['master', 'netting', 'agreement', 'isda', 'fw...
# 6    ['fw', 'nothing', 'kennedy', 'tie', 'medicine'...
# 7    ['fw', 'huber', 'gas', 'western', 'project', '...
# 8    ['nothing', 'fw', 'communication', 'attorney',...
# 9    ['isda', 'inc', 'agreement', 'energy', 'master...
# 10   ['wire', 'sonat', 'colonial', 'park', '195', '...
# 11   ['crestone', 'purchase', 'november', 'creek', ...
# 12   ['fw', 'eol', 'isda', 'synchronization', 'log'...
# 13   ['riverside', 'waste', 'fw', 'mgt', 'county', ...
# 14   ['nui', 'agreement', 'firm', 'master', 'allegh...
# 15   ['fw', 'tw', 'devil', 'meeting', 'sun', '637',...
# 16   ['fw', '2002', 'plan', 'nothing', 'tw', 'revie...
# 17   ['devil', 'sun', 'tw', 'bullets', 'fw', 'updat...
# 18   ['badge', 'generators', 'whats', 'receipts', '...
# 19   ['tw', 'socal', 'fw', 'capacity', 'plan', '200...
# 20   ['fw', 'tw', 'bullets', 'questar', 'meeting', ...
# 21   ['west', 'rotation', 'desk', 'lon', 'uncertain...
# 22   ['nothing', 'weather', 'travel', 'ok', 'wanted...
# 23   ['fw', 'enron', 'rto', 'ferc', 'meeting', 'et'...
# 24   ['frontera', 'ercot', 'fw', 'orrow', 'position...
# 25   ['10', 'weather', 'fw', 'meeting', 'fundies', ...
# 26   ['test', 'uct', 'lodi', 'eol', 'season', 'open...
# 27   ['meeting', 'draft', 'agreement', 'tva', 'eei'...
# 28   ['fw', 'tw', '00', 'sept', 'estimate', 'gas', ...
# 29   ['request', 'route', 'approved', 'fw', 'approv...
# ..                                                 ...
# 121  ['running', 'firm', 'rob', 'one', 'stub', 'tow...
# 122  ['meeting', 'fw', 'operations', 'enron', 'cong...
# 123  ['fw', 'rac', 'credit', 'board', 'dash', 'meet...
# 124  ['fw', 'hourly', 'new', 'jr', 'epmi', 'du', 'b...
# 125  ['nothing', 'game', 'fw', 'football', 'tonight...
# 126  ['fw', 'central', 'postings', 'ran', 'region',...
# 127  ['associate', 'program', 'analyst', 'executive...
# 128  ['west', 'book', 'new', 'books', 'trv', 'fw', ...
# 129  ['murdock', 'jerry', 'attend', 'telephone', 's...
# 130  ['northwest', 'book', 'business', 'uct', 'ttc'...
# 131  ['01', 'schedule', 'realtime', 'length', 'new'...
# 132  ['fw', 'lucas', 'melia', 'driver', 'office', '...
# 133  ['fw', 'tag', 'oasis', 'detail', 'ncpa', 'shas...
# 134  ['carl', 'real', 'model', 'fw', 'url', 'hey', ...
# 135  ['new', 'paths', 'length', 'abb', 'cuts', 'tim...
# 136  ['tw', 'gallup', 'pueblo', 'request', 'approva...
# 137  ['outage', 'bpa', 'account', 'voice', 'numbers...
# 138  ['ferc', 'iso', 'px', 'california', 'order', '...
# 139  ['ferc', 'meeting', 'nov', '15th', 'friday', '...
# 140  ['tw', 'fw', 'amarillo', 'gas', 'season', 'ope...
# 141  ['agreement', 'contract', 'enfolio', 'fw', 'cr...
# 142  ['eddie', 'wheel', 'reliability', 'tie', '06',...
# 143  ['cers', 'status', 'trading', 'oz', 'owls', 'o...
# 144  ['var', 'nothing', 'ps', 'positions', 'book', ...
# 145  ['packers', 'bc', 'barrett', 'tmas', 'gas', 'a...
# 146  ['isda', 'enron', 'guaranty', 'eta', 'agreemen...
# 147  ['farewell', 'na', 'son', 'getting', 'epmi', '...
# 148  ['checkout', 'deal', 'apb', '01', 'deals', 'na...
# 149  ['cst', '06980', 'trader', 'meeting', 'rm', 'c...
# 150  ['meeting', 'thank', 'remove', 'board', 'commi...
#
# [151 rows x 11 columns]
